# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“Pengenalan Python, VSCode, dan Koneksi ke GitHub”**
#
# **Disusun Oleh :**
#
# **Adib Ridho Putra**
#
# **2611532018**
#
# **Dosen Pengampu:**
#
# **Dr. Ir. Wahyudi, S.T., M.T.**
#
# **Asisten Praktikum:**
#
# **Rifky Yuliandra**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum “Pengenalan Python, VSCode, dan Koneksi ke GitHub” yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Struktur Data. Praktikum ini berfokus pada pembahasan pengenalan Python, penggunaan Visual Studio Code (VSCode), serta koneksi dan penggunaan GitHub.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep dasar penggunaan Python, VSCode, dan koneksi ke GitHub pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Perkembangan teknologi dalam bidang pemrograman membuat pemahaman terhadap bahasa pemrograman dan perangkat pendukungnya menjadi hal yang penting bagi mahasiswa Informatika. Python merupakan salah satu bahasa pemrograman yang dapat digunakan untuk mempelajari dasar-dasar pemrograman. Selain bahasa pemrograman, diperlukan juga perangkat pengembangan seperti Visual Studio Code (VSCode) serta platform GitHub untuk membantu proses pengembangan dan pengelolaan program.
#
# Oleh karena itu, praktikum ini dilakukan untuk mengenalkan Python, VSCode, serta koneksi ke GitHub sebagai dasar dalam melakukan pengembangan program dan pengelolaan proyek.
#
# ## 1.2 Tujuan
# 1. Mengenal dasar penggunaan bahasa pemrograman Python.
# 2. Mengenal dan menggunakan Visual Studio Code (VSCode) sebagai lingkungan pengembangan program.
# 3. Memahami cara menghubungkan proyek dengan GitHub.
#
# ## 1.3 Manfaat
# 1. Menambah pemahaman mengenai penggunaan Python dalam pemrograman.
# 2. Meningkatkan kemampuan dalam menggunakan VSCode untuk membuat dan mengelola program.
# 3. Mengetahui dasar penggunaan GitHub untuk menyimpan dan mengelola proyek pemrograman.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Python merupakan bahasa pemrograman tingkat tinggi yang memiliki sintaks sederhana dan mudah dipahami. Python dapat digunakan untuk membuat berbagai jenis program dan banyak digunakan dalam pembelajaran pemrograman.
# Visual Studio Code merupakan code editor yang digunakan untuk menulis, mengedit, dan menjalankan program. VSCode mendukung berbagai bahasa pemrograman, termasuk Python, serta menyediakan berbagai fitur yang membantu proses pengembangan program.
# GitHub merupakan platform yang digunakan untuk menyimpan dan mengelola kode program secara daring. GitHub juga dapat digunakan untuk melakukan kolaborasi dan menyimpan riwayat perubahan pada suatu proyek.
# Koneksi VSCode dengan GitHub memungkinkan proyek yang dibuat melalui VSCode untuk dihubungkan dengan repository GitHub sehingga kode dapat disimpan dan dikelola secara daring

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "PrakAlpro_B_2611532018"

# %%
# Program pertama
"""
Komentar
dua baris atau lebih 
pertemuan 1 praktikum alpro
"""
print("Hello World")
print()
print("Program ini menghasilkan")
print("Empat baris output")
print("/ \\ // \\\\ /// \\\\\\")
print("program ini" + " dibuat oleh a\n"
+ "Adib Ridho Putra 2611532018." )
# Out:
# Hello World
#
# Program ini menghasilkan
# Empat baris output
# / \ // \\ /// \\\
# program ini dibuat oleh a
# Adib Ridho Putra 2611532018.

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama sampai keenam kode ini berfungsi sebagai penjelas sebuah struktur program.
# 2. Bagian ketujuh sampai terakhir kode ini menghasilkan sebuah output.
# 3. Program ini dijalankan menggunakan bahasa python.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal : Buatlah sebuah file program python bebas dengan nama tugas1_nim.py!**

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "PrakAlpro_B_2611532018"

# %%
print("=== Jadwal Kuliah Adib Ridho Putra IF Kelas B ===")
print("Senin  : Aljabar Linear, Matematika Diskrit, Bahasa Inggris")
print("Selasa : Kalkulus")
print("Rabu   : Pendidikan Agama, Algoritma dan Pemrograman")
print("Kamis  : Praktikum Algoritma dan Pemrograman")
print("Jumat  : Organisasi dan Arsitektur Komputer")
print("=================================================")
# Out:
# === Jadwal Kuliah Adib Ridho Putra IF Kelas B ===
# Senin  : Aljabar Linear, Matematika Diskrit, Bahasa Inggris
# Selasa : Kalkulus
# Rabu   : Pendidikan Agama, Algoritma dan Pemrograman
# Kamis  : Praktikum Algoritma dan Pemrograman
# Jumat  : Organisasi dan Arsitektur Komputer
# =================================================

# %% [markdown]
# **Penjelasan :** Program tugas ini menampilkan jadwal perkuliahan dari Adib Ridho Putra. Perintah print() untuk menghasilkan output berupa teks yang berisi jadwal perkuliahan dari hari Senin sampai hari Jumat. Karakter = yang disusun berfungsi sebagai pembatas dengan tujuan agar tampilan jadwal terlihat lebih rapi.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa Python merupakan bahasa pemrograman yang dapat digunakan untuk membuat dan menjalankan program dengan sintaks yang sederhana. Visual Studio Code dapat digunakan sebagai lingkungan untuk menulis dan menjalankan kode Python, sedangkan GitHub dapat digunakan untuk menyimpan dan mengelola proyek secara daring.
#
# Dalam praktikum ini, penulis mempelajari dasar penggunaan Python, VSCode, serta koneksi ke GitHub. Dengan memahami ketiga hal tersebut, proses pembuatan, pengelolaan, dan penyimpanan program dapat dilakukan dengan lebih terstruktur.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation, "Python Documentation," Python, [Online]. Tersedia: https://docs.python.org/3/. [Diakses 10 September 2026].
#
# [2] Microsoft, "Visual Studio Code Documentation," Visual Studio Code, [Online]. Tersedia: https://code.visualstudio.com/docs. [Diakses 10 September 2026].
#
# [3] GitHub, "GitHub Documentation," GitHub, [Online]. Tersedia: https://docs.github.com/. [Diakses 10 September 2026].
